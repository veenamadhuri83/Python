# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
# can you create a empty braches

# %%
u = ()

# %%
type(u)
# Out:
# tuple

# %%
u=(,)
# Out:
#   Cell In[54], line 1
#     u=(,)
#        ^
# SyntaxError: invalid syntax

# %%
type(u)
# Out:
# tuple

# %%
Series
# Out:
# pandas.core.series.Series

# %%
# SERIES IS AN ONE DIMENSIONAL ARRAY IT WILL D
# SERIES IS A SET OF VALUES

# %%
y=[4,5,6,78]
Series(y)
# Out:
# 0     4
# 1     5
# 2     6
# 3    78
# dtype: int64

# %%
y=[4,5,6,78]
Series(y,index=["a","b","c","d"])
# Out:
# a     4
# b     5
# c     6
# d    78
# dtype: int64

# %%
# above program 
# index position = 0
# index value = a

# %%
# bringing the values from the list

# %%
y=[4,5,6,78]
b=Series(y,index=["a","b","c","d"])

# %%
b[0]
# Out:
# C:\Users\mr\AppData\Local\Temp\ipykernel_2564\172979841.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   b[0]
# np.int64(4)

# %%
# type of series = class

# as per this oops = as per this a class is used to save n number of functions 
# to bring out of function we use "."

# %%
b.iloc[0]

# np means numpy
# this is position based index
# Out:
# np.int64(4)

# %%
# to index a function from series we use iloc

# %%
b.loc["a"]

# this is the value based index
# Out:
# np.int64(4)

# %%
b.iloc[[0,2]]
# Out:
# a    4
# c    6
# dtype: int64

# %%
b.iloc[[0,1,2]]
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
b.loc[["a","b","c"]]
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
b.iloc[0:2]
# Out:
# a    4
# b    5
# dtype: int64

# %%
b.loc["a":"b"]
# Out:
# a    4
# b    5
# dtype: int64

# %%
# what is the difference b/w values and position 
# what ever we are seeing is value 
# what ever we are not seeing is a position

# %%
b.loc["a"] = 10
b
# Out:
# a    10
# b     5
# c     6
# d    78
# dtype: int64

# %%
b.loc[["a","b","c"]]=[10,12,14]
b
# Out:
# a    10
# b    12
# c    14
# d    78
# dtype: int64

# %%
# how to remove the value

# %%
b.drop
# Out:
# <bound method Series.drop of a    10
# b    12
# c    14
# d    78
# dtype: int64>

# %%
b.drop("a")
# Out:
# b    12
# c    14
# d    78
# dtype: int64

# %%
b.drop(["a","b","c"])
# Out:
# d    78
# dtype: int64

# %%
b.drop(["a","b"])
# Out:
# c    14
# d    78
# dtype: int64

# %%
b.drop(["a","b"],inplace=True)

# %%
b
# Out:
# c    14
# d    78
# dtype: int64

# %%
b.drop(["a","b"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 b.drop(["a","b"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:5356, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5259 def drop(
#    5260     self,
#    5261     labels: IndexLabel | None = None,
#    (...)
#    5268     errors: IgnoreRaise = "raise",
#    5269 ) -> Series | None:
#    5270     """
#    5271     Return Series with specified index labels removed.
#    5272
#    (...)
#    5354     dtype: float64
#    5355     """
# -> 5356     return super().drop(
#    5357         labels=labels,
#    5358         axis=axis,
#    5359         index=index,
#    5360         columns=columns,
#    5361         level=level,
#    5362         inplace=inplace,
#    5363         errors=errors,
#    5364     )
#
# ...

# %%
help(b.min)
# Out:
# Help on method min in module pandas.core.series:
#
# min(
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     **kwargs
# ) method of pandas.core.series.Series instance
#     Return the minimum of the values over the requested axis.
#
#     If you want the *index* of the minimum, use ``idxmin``. This is the equivalent of the ``numpy.ndarray`` method ``argmin``.
#
#     Parameters
#     ----------
#     axis : {index (0)}
#         Axis for the function to be applied on.
#         For `Series` this parameter is unused and defaults to 0.
#
#         For DataFrames, specifying ``axis=None`` will apply the aggregation
#         across both axes.
#
#         .. versionadded:: 2.0.0
#
#     skipna : bool, default True
#         Exclude NA/null values when computing the result.
#     numeric_only : bool, default False
#         Include only float, int, boolean columns. Not implemented for Series.
#
#     **kwargs
# ...

# %%
#Add I to every element in list

k=[10,12,13,15]
g=[]
for i in k:
    g.append(i+1)
else:
    print(g)
# Out:
# [11, 13, 14, 16]

# %%
import pandas as pd
k=pd.Series([10,12,13,15])
print(k+2)
# Out:
# 0    12
# 1    14
# 2    15
# 3    17
# dtype: int64

# %%
k%2==0
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
k[k%2==0]
# Out:
# 0    10
# 1    12
# dtype: int64

# %%
k.drop(k.loc[k%2==0].index)
# Out:
# 2    13
# 3    15
# dtype: int64

# %%
h=k.mean()
def test(x):
    if x>h:
        return 1
    else:
        return 0
k.map(test)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# dtype: int64

# %%
h=k.mean()
def test(x):
    if x>h:
        return 1
    else:
        return 0
k.apply(test)
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# dtype: int64

# %%
j=range(2,22,2)
k=range(3,33,3)
l=range(4,44,4)
DataFrame([j,k,l])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 k=range(3,33,3)
#       3 l=range(4,44,4)
# ----> 4 DataFrame([j,k,l])
#
# NameError: name 'DataFrame' is not defined

# %%
k.loc[["b","c"],[30,35]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 k.loc[["b","c"],[30,35]]
#
# AttributeError: 'range' object has no attribute 'loc'

# %%
k.loc[["a","b"],[35,40,45,50]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 k.loc[["a","b"],[35,40,45,50]]
#
# AttributeError: 'range' object has no attribute 'loc'

# %%
k.loc[["b","c"]:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 k.loc[["b","c"]:]
#
# AttributeError: 'range' object has no attribute 'loc'

# %%
k.iloc[[1:2]:]
# Out:
#   Cell In[7], line 1
#     k.iloc[[1:2]:]
#              ^
# SyntaxError: invalid syntax

# %%
k.iloc[:1,:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 k.iloc[:1,:5]
#
# AttributeError: 'range' object has no attribute 'iloc'

# %%
k.loc[0:
